# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('population_switzerland_UPDATED.csv',sep=';')
df.head()
# Out:
#          Gemeindename  Long  Lat  Gemeindecode  Bevšlkerung Einwohner 2019  \
# 0     Aeugst am Albis   NaN  NaN             1                        1981
# 1  Affoltern am Albis   NaN  NaN             2                       12303
# 2          Bonstetten   NaN  NaN             3                        5572
# 3     Hausen am Albis   NaN  NaN             4                        3751
# 4            Hedingen   NaN  NaN             5                        3778
#
#   Bevšlkerung VerŠnderung in % 2010-2019  \
# 0                             8,60745614
# 1                            10,92777928
# 2                            8,005427408
# 3                            11,63690476
# 4                            10,79178886
#
#   Bevšlkerung Bevšlkerungs-dichte pro km_ 2019  \
# 0                                  250,4424779
# 1                                  1161,756374
# 2                                  749,9327052
# 3                                  275,8088235
# ...

# %%
sns.relplot(x="Bevšlkerung Einwohner 2019",y="Bevšlkerung Bevšlkerungs-dichte pro km_ 2019", data=df, color="green", alpha=0.5, kind="scatter")
plt.show()
